# %% [markdown]
# # Initialization

# %%
# Initialization
#import pyspark as spark
from pyspark.sql import SparkSession

# incase the spark context already exists

spark = SparkSession \
        .builder \
        .appName("Project2") \
        .getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/21 23:06:10 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Global Constants
random_seed = 42

path_to_file_local = "games_cleaned.csv"
path_to_file_hadoop = ""

# %%
from pyspark.sql.types import *


# TODO: Finish this... I'm too tired to finish this tonight
types = StructType([
    StructField('AppId', IntegerType(), True),
    StructField('Name', StringType(), True),
    StructField('Released date', StringType(), True),
    StructField('Publishers', StringType(), True), 
    StructField('Categories', StringType(), True),
    StructField('Genres', StringType(), True),
    StructField('Tags', StringType(), True),
    StructField('estimated_owner_mid', IntegerType(), True),
    StructField('Average playtime forever', DoubleType(), True),
    StructField('Average playtime two weeks', DoubleType(), True),
    StructField('Median playtime forever', DoubleType(), True),
    StructField('Median playtime two weeks', DoubleType(), True),
    StructField('Developers', StringType(), True),
    StructField('Linux', IntegerType(), True),
    StructField('Metacritic score', DoubleType(), True),
    StructField('User score', DoubleType(), True),
    StructField('Positive', IntegerType(), True),
    StructField('Negative', IntegerType(), True),
    StructField('DiscountDLC count', IntegerType(), True),
    StructField('Supported languages', StringType(), True),
    StructField('Full audio languages', StringType(), True),
    StructField('Windows', IntegerType(), True),
    StructField('Mac', IntegerType(), True),
    StructField('Peak CCU', IntegerType(), True),
    StructField('Required age', IntegerType(), True),
    StructField('Price', DoubleType(), True),
    StructField('Estimated owners', StringType(), True),
    StructField('_c0', IntegerType(), True)
])


data = spark.read.schema(types).csv(path_to_file_local, header=True)
data.columns
# Out:
# ['AppId',
#  'Name',
#  'Released date',
#  'Publishers',
#  'Categories',
#  'Genres',
#  'Tags',
#  'estimated_owner_mid',
#  'Average playtime forever',
#  'Average playtime two weeks',
#  'Median playtime forever',
#  'Median playtime two weeks',
#  'Developers',
#  'Linux',
#  'Metacritic score',
#  'User score',
#  'Positive',
#  'Negative',
#  'DiscountDLC count',
#  'Supported languages',
#  'Full audio languages',
#  'Windows',
#  'Mac',
#  'Peak CCU',
#  'Required age',
#  'Price',
#  'Estimated owners',
#  '_c0']

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ### Train Test Split

# %%
from pyspark.ml.feature import VectorAssembler

# Note: We probably need to translate some of the strings to integer enumerations...
'''
data = data.drop('Publishers', 'Categories', 'Genres', 'Tags', 'estimated_owner_mid', 'Average playtime forever', \
                  'Average playtime two weeks', 'Median playtime forever', 'Median playtime two weeks', 'Developers', \
                  'estimated_owners_mid', 'Linux', 'Metacritic score', 'User score', 'Positive', 'Negative', 'DiscountDLC count', \
                  'Supported languages', 'Full audio languages', 'Windows', 'Mac', 'Peak CCU', 'Required age', 'Price', \
                  'AppID', 'Name', 'Release date', 'Estimated owners', '_c0'
                    )
'''
assembler = VectorAssembler(
    inputCols=data.drop('estimated_revenue', 'Publishers', 'Categories', 'Genres', 'Tags', 'estimated_owner_mid').columns,
    outputCol='features'
)

data_separeted = assembler.transform(data)

# %%
train, test = data_separeted.randomSplit([0.7, 0.3], seed=random_seed)

# %%
# SVM for determining if a game will sell well
from pyspark.ml.classification import LinearSVC
svm = LinearSVC(labelCol='estimated_revenue', featuresCol='features')

# default training
svm.fit(t)
# Out:
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# Cell In[14], line 6
#       3 svm = LinearSVC(labelCol='estimated_revenue')
#       5 # default training
# ----> 6 svm.fit(train)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pyspark/ml/base.py:203, in Estimator.fit(self, dataset, params)
#     201         return self.copy(params)._fit(dataset)
#     202     else:
# --> 203         return self._fit(dataset)
#     204 else:
#     205     raise TypeError(
#     206         "Params must be either a param map or a list/tuple of param maps, "
#     207         "but got %s." % type(params)
#     208     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pyspark/ml/util.py:211, in try_remote_fit.<locals>.wrapped(self, dataset)
#     209     return self._copyValues(model)
#     210 else:
# --> 211     return f(self, dataset)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pyspark/ml/wrapper.py:417, in JavaEstimator._fit(self, dataset)
#     415 @try_remote_fit
#     416 def _fit(self, dataset: DataFrame) -> JM:
# --> 417     java_model = self._fit_java(dataset)
#     418     model = self._create_model(java_model)
#     419     return self._copyValues(model)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pyspark/ml/wrapper.py:413, in JavaEstimator._fit_java(self, dataset)
#     410 assert self._java_obj is not None
#     412 self._transfer_params_to_java()
# --> 413 return self._java_obj.fit(dataset._jdf)
#
# File /opt/anaconda3/lib/python3.12/site-packages/py4j/java_gateway.py:1362, in JavaMember.__call__(self, *args)
#    1356 command = proto.CALL_COMMAND_NAME +\
#    1357     self.command_header +\
#    1358     args_command +\
#    1359     proto.END_COMMAND_PART
#    1361 answer = self.gateway_client.send_command(command)
# -> 1362 return_value = get_return_value(
#    1363     answer, self.gateway_client, self.target_id, self.name)
#    1365 for temp_arg in temp_args:
#    1366     if hasattr(temp_arg, "_detach"):
#
# File /opt/anaconda3/lib/python3.12/site-packages/pyspark/errors/exceptions/captured.py:269, in capture_sql_exception.<locals>.deco(*a, **kw)
#     265 converted = convert_exception(e.java_exception)
#     266 if not isinstance(converted, UnknownException):
#     267     # Hide where the exception came from that shows a non-Pythonic
#     268     # JVM exception message.
# --> 269     raise converted from None
#     270 else:
#     271     raise
#
# IllegalArgumentException: [FIELD_NOT_FOUND] No such struct field `features` in `_c0`, `AppID`, `Name`, `Release date`, `Estimated owners`, `Peak CCU`, `Required age`, `Price`, `DiscountDLC count`, `Supported languages`, `Full audio languages`, `Windows`, `Mac`, `Linux`, `Metacritic score`, `User score`, `Positive`, `Negative`, `Average playtime forever`, `Average playtime two weeks`, `Median playtime forever`, `Median playtime two weeks`, `Developers`, `Publishers`, `Categories`, `Genres`, `Tags`, `estimated_owners_mid`, `estimated_revenue`. SQLSTATE: 42704

# %%
# Out:
# Column<'estimated_revenue'>

# %%
spark.stop()
